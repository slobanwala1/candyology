# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
data = pd.read_csv("commodity_trade_statistics_data.csv", low_memory=False)

# %%
data
# Out:
#         country_or_area  year comm_code  \
# 0           Afghanistan  2016    010410
# 1           Afghanistan  2016    010420
# 2           Afghanistan  2008    010210
# 3               Albania  2016    010290
# 4               Albania  2016    010392
# ...                 ...   ...       ...
# 8225866        Zimbabwe  2001     TOTAL
# 8225867        Zimbabwe  2001     TOTAL
# 8225868        Zimbabwe  2000     TOTAL
# 8225869        Zimbabwe  1995     TOTAL
# 8225870        Zimbabwe  1995     TOTAL
#
#                                                commodity       flow  \
# 0                                            Sheep, live     Export
# 1                                            Goats, live     Export
# 2                Bovine animals, live pure-bred breeding     Import
# 3        Bovine animals, live, except pure-bred breeding     Import
# 4          Swine, live except pure-bred breeding > 50 kg     Import
# ...

# %%
data.groupby('country_or_area')

# %%
def getData(country, commodity, title):
    all_data = data[(data['commodity']==commodity) & (data['year']>=1995) & (data['country_or_area']==country) & (data['flow']=='Import')]
    year_and_quantity_data = {'Year': all_data['year'], 'Quantity': all_data['quantity']}
    df = pd.DataFrame(year_and_quantity_data, columns= ['Year', 'Quantity'])
    df.reset_index(drop=True, inplace=True)
    x_axis = df['Year']
    y_axis = df['Quantity']
    plt.plot(x_axis, y_axis, label=country)
    plt.title(title)
    plt.xlabel("Year")
    plt.ylabel("Quantity x 100,000,000")

# %%
getData("USA", 'Sugar confectionery not chewing gum, no cocoa content', "Confectionary Imports With No Chocolate")
getData("China", 'Sugar confectionery not chewing gum, no cocoa content', "Confectionary Imports With No Chocolate")
getData("Russian Federation", 'Sugar confectionery not chewing gum, no cocoa content', "Confectionary Imports With No Chocolate")
getData("Germany", 'Sugar confectionery not chewing gum, no cocoa content', "Confectionary Imports With No Chocolate")
getData("Canada", 'Sugar confectionery not chewing gum, no cocoa content', "Confectionary Imports With No Chocolate")
plt.legend(loc="upper right")

# %%
getData("USA", 'Chocolate and other food preps containing cocoa > 2 k', "Chocolate Foods Imports")
getData("China", 'Chocolate and other food preps containing cocoa > 2 k', "Chocolate Foods Imports")
getData("Russian Federation", 'Chocolate and other food preps containing cocoa > 2 k', "Chocolate Foods Imports")
getData("Germany", 'Chocolate and other food preps containing cocoa > 2 k', "Chocolate Foods Imports")
getData("Canada", 'Chocolate and other food preps containing cocoa > 2 k', "Chocolate Foods Imports")
plt.legend(loc="upper right")

# %%
pie_data = data[(data['commodity']=='Refined sugar, in solid form, flavoured or coloured') & (data['year']==2015) & (data['flow']=='Export')]
pie_data
# Out:
#               country_or_area  year comm_code  \
# 1337119             Argentina  2015    170191
# 1338200             Australia  2015    170191
# 1339159               Austria  2015    170191
# 1341892               Belarus  2015    170191
# 1342335               Belgium  2015    170191
# ...                       ...   ...       ...
# 1414063  United Arab Emirates  2015    170191
# 1414424        United Kingdom  2015    170191
# 1416131                   USA  2015    170191
# 1418103                 Yemen  2015    170191
# 1418395                Zambia  2015    170191
#
#                                                  commodity    flow  trade_usd  \
# 1337119  Refined sugar, in solid form, flavoured or col...  Export       1012
# 1338200  Refined sugar, in solid form, flavoured or col...  Export    1140851
# 1339159  Refined sugar, in solid form, flavoured or col...  Export    1898123
# 1341892  Refined sugar, in solid form, flavoured or col...  Export        100
# ...

# %%
crazyPieChart = {'Country': pie_data['country_or_area'], 'Year': pie_data['year'], 'Quantity': pie_data['quantity']
        }

df = pd.DataFrame(crazyPieChart, columns= ['Country', 'Quantity'])

df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                  Country    Quantity
# 0              Argentina       600.0
# 1              Australia    113470.0
# 2                Austria    814693.0
# 3                Belarus        30.0
# 4                Belgium   2160186.0
# ..                   ...         ...
# 86  United Arab Emirates   1570725.0
# 87        United Kingdom   1743716.0
# 88                   USA  20969770.0
# 89                 Yemen     19500.0
# 90                Zambia     35530.0
#
# [91 rows x 2 columns]

# %%
labels = df['Country']
plt.title(f'Refined sugar Imports for {labels.count()} countries')
plt.pie(df['Quantity'], labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fdd1abc7190>,
# ...
#  [Text(1.0999999998511518, 1.809602877141789e-05, 'Argentina'),
#   Text(1.0999945632347436, 0.0034584467620371326, 'Australia'),
#   Text(1.099550384505828, 0.031447606158268915, 'Austria'),
#   Text(1.0985736330180975, 0.055999757476428796, 'Belarus'),
#   Text(1.0933323521048341, 0.12093125254007457, 'Belgium'),
#   Text(1.083972911965523, 0.1870901550723193, 'Bosnia Herzegovina'),
#   Text(1.083681153071612, 0.18877276942764237, 'Botswana'),
#   Text(1.0834285317271557, 0.190217287961793, 'Brazil'),
#   Text(1.083000770340036, 0.1926378245384037, 'Bulgaria'),
#   Text(1.0794715054980604, 0.21152132000758528, 'Canada'),
#   Text(1.0758125719078195, 0.2294064299994286, 'China'),
#   Text(1.0636535862245056, 0.28043011341820684, 'China, Hong Kong SAR'),
#   Text(1.0490427164961533, 0.33092201342064215, 'Colombia'),
#   Text(1.0489062285610022, 0.33135437779805266, 'Costa Rica'),
# ...

# %%
plt.title('Refined sugar Imports Around the World')
x_axis = df['Country']
y_axis = df['Quantity']
plt.xticks(rotation=90)
plt.bar(x_axis, y_axis,)
# Out:
# <BarContainer object of 91 artists>
